// %%
// val: describe el curso (no cambia durante la ejecución)
val nombreCurso = "Big Data con Scala"
val numeroDias  = 28
val horasPorDia = 5.0

println(s"Curso: $nombreCurso")
println(s"Duración: $numeroDias días × $horasPorDia h/día = ${numeroDias * horasPorDia} horas")
// Out:
// Curso: Big Data con Scala
// Duración: 28 días × 5.0 h/día = 140.0 horas
// nombreCurso: String = "Big Data con Scala"
// numeroDias: Int = 28
// horasPorDia: Double = 5.0

// %%
scala.util.Properties.versionString
// Out:
// res1: String = "version 2.13.14"

// %%
// var: el contador de sesiones cambia a lo largo del programa
var sesionesCompletadas = 0
println(s"Sesiones completadas al inicio: $sesionesCompletadas")

sesionesCompletadas = sesionesCompletadas + 1
println(s"Después de la Sesión 1: $sesionesCompletadas")

sesionesCompletadas += 1
println(s"Después de la Sesión 2: $sesionesCompletadas")
// Out:
// Sesiones completadas al inicio: 0
// Después de la Sesión 1: 1
// Después de la Sesión 2: 2
// sesionesCompletadas: Int = 2

// %%
// Descomenta la siguiente línea para ver el error de compilación:
// numeroDias = 30
// error: reassignment to val

// %%
val a: Double = 15.0
val b: Double = 4.0

val suma     = a + b
val resta    = a - b
val producto = a * b
val division = a / b
val modulo   = a % b

println("=== Calculadora Scala ===")
println(f"  $a%.1f + $b%.1f = $suma%.1f")
println(f"  $a%.1f - $b%.1f = $resta%.1f")
println(f"  $a%.1f × $b%.1f = $producto%.1f")
println(f"  $a%.1f ÷ $b%.1f = $division%.4f")
println(f"  $a%.1f %% $b%.1f = $modulo%.1f")
// Out:
// === Calculadora Scala ===
//   15,0 + 4,0 = 19,0
//   15,0 - 4,0 = 11,0
//   15,0 × 4,0 = 60,0
//   15,0 ÷ 4,0 = 3,7500
//   15,0 % 4,0 = 3,0
// a: Double = 15.0
// b: Double = 4.0
// suma: Double = 19.0
// resta: Double = 11.0
// producto: Double = 60.0
// division: Double = 3.75
// modulo: Double = 3.0

// %%
// División entera con Int
val x: Int = 15
val y: Int = 4

println(s"División entera: $x / $y = ${x / y}")
println(s"Resto:           $x % $y = ${x % y}")

// Comparaciones
println(s"\n¿$a > $b?   ${a > b}")
println(s"¿$a == $b?  ${a == b}")
println(s"¿$a != $b?  ${a != b}")
// Out:
// División entera: 15 / 4 = 3
// Resto:           15 % 4 = 3
//
// ¿15.0 > 4.0?   true
// ¿15.0 == 4.0?  false
// ¿15.0 != 4.0?  true
// x: Int = 15
// y: Int = 4

// %%
val pesoKg    = 75.0
val alturaMts = 1.78

val imc = pesoKg / (alturaMts * alturaMts)

val categoria =
  if      (imc < 18.5) "Bajo peso"
  else if (imc < 25.0) "Normal"
  else if (imc < 30.0) "Sobrepeso"
  else                 "Obesidad"

println(f"IMC: $imc%.2f → $categoria")

// %%
val nombre       = "Carlos García"
val edad         = 32
val nota         = 8.756
val aprobado     = nota >= 5.0
val rutaInformes = raw"C:\Informes\Alumnos\2024"

// Interpolador s
println(s"Alumno: $nombre")
println(s"Edad:   $edad años")
println(s"¿Ha aprobado? $aprobado")
println(s"Años hasta jubilación (65): ${65 - edad}")
// Out:
// Alumno: Carlos García
// Edad:   32 años
// ¿Ha aprobado? true
// Años hasta jubilación (65): 33
// nombre: String = "Carlos García"
// edad: Int = 32
// nota: Double = 8.756
// aprobado: Boolean = true
// rutaInformes: String = "C:\\Informes\\Alumnos\\2024"

// %%
// Interpolador f: formato decimal
println(f"Nota final:    $nota%.2f")
println(f"Nota sobre 10: $nota%05.2f")

// Interpolador raw: ruta Windows sin problemas con \
println(s"\nRuta de informes: $rutaInformes")
// Out:
// Nota final:    8,76
// Nota sobre 10: 08,76
//
// Ruta de informes: C:\Informes\Alumnos\2024

// %%
val nombre = "Angie"
val edad = 27
val altura = 1.50
val trabajando = true

// Interpolador s corregido
println(s"nombre: Angie")
println(s"edad: 27")
println(s"altura: 1.50")
println(s"trabajando: $trabajando")
// Out:
// nombre: Angie
// edad: 27
// altura: 1.50
// trabajando: true
// nombre: String = "Angie"
// edad: Int = 27
// altura: Double = 1.5
// trabajando: Boolean = true

// %%
val minutosTotales = 137


val horas = minutosTotales / 60
val minutosRestantes = minutosTotales % 60

//  el interpolador s
println(s"$minutosTotales minutos = $horas horas y $minutosRestantes minutos")
// Out:
// 137 minutos = 2 horas y 17 minutos
// minutosTotales: Int = 137
// horas: Int = 2
// minutosRestantes: Int = 17

// %%
val a = 49.99
val b = 67.50


val esMenor = a < b          // Esto dará true
val sonIguales = a == b      // Esto dará false (usa == para comparar)
val resultadoResta = b - a    // Esto dará la diferencia

// División entera con Int 
println(s"$a < $b ? ${a < b}")
println(s"$a = $b ? ${a == b}")
println(s"$b - $a = ${b - a}")
// Out:
// 49.99 < 67.5 ? true
// 49.99 = 67.5 ? false
// 67.5 - 49.99 = 17.509999999999998
// a: Double = 49.99
// b: Double = 67.5
// esMenor: Boolean = true
// sonIguales: Boolean = false
// resultadoResta: Double = 17.509999999999998

// %%
val producto="teclado mecánico" 
val precio=89.99
val unidades =3
val enstock = true  



println( s"Producto: $producto ")
println(s"Precio: $precio ")
println(s"Unidades: $unidades")
println(f"subtotal: ${precio * unidades}%.2f")
println(s"enstock: $enstock")
// Out:
// Producto: teclado mecánico
// Precio: 89.99
// Unidades: 3
// subtotal: 269,97
// enstock: true
// producto: String = "teclado mecánico"
// precio: Double = 89.99
// unidades: Int = 3
// enstock: Boolean = true

// %%
val edad: Int = 17

val mensaje = 
  if (edad < 0) "edad no válida"
  else if (edad < 12) "niño"
  else if (edad < 18) "adolescente"
  else if (edad < 65) "adulto"
  else "senior"


println(s"edad : $mensaje = edad : $mensaje")
// Out:
// edad : adolescente = edad : adolescente
// edad: Int = 17
// mensaje: String = "adolescente"

// %%
//rango excluusivo :1 hasta 10(incluye el 10)
for (i <- 10 to 1 by -1 )
println (s"i  > $i")
// Out:
// i  > 10
// i  > 9
// i  > 8
// i  > 7
// i  > 6
// i  > 5
// i  > 4
// i  > 3
// i  > 2
// i  > 1

// %%
for  (i <- 1 to 20 )
println (s"i  <  $i")
 val numeros = List (3,6,12,15,18)
 for (n <- 1 to 20 if n % 3 == 0)
 println(s"Multiplo de 3  : $n")
// Out:
// i  <  1
// i  <  2
// i  <  3
// i  <  4
// i  <  5
// i  <  6
// i  <  7
// i  <  8
// i  <  9
// i  <  10
// i  <  11
// i  <  12
// i  <  13
// i  <  14
// i  <  15
// i  <  16
// i  <  17
// i  <  18
// i  <  19
// i  <  20
// Multiplo de 3  : 3
// Multiplo de 3  : 6
// Multiplo de 3  : 9
// Multiplo de 3  : 12
// Multiplo de 3  : 15
// Multiplo de 3  : 18
// numeros: List[Int] = List(3, 6, 12, 15, 18)

// %%
val numeroDia: Int = 3
     val dia =  dia1 match { case "lunes "}
